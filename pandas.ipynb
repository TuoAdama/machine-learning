# %%
import pandas as pd

# %%
dataframe = pd.read_csv("ozone.csv", delimiter=";")

# %%
print(dataframe)
# Out:
#      obs  maxO3    T9   T12   T15  Ne9  Ne12  Ne15      Vx9     Vx12     Vx15  \
# 0    601     87  15,6  18,5  18,4    4     4     8   0,6946  -1,7101  -0,6946
# 1    602     82    17  18,4  17,7    5     5     7  -4,3301       -4       -3
# 2    603     92  15,3  17,6  19,5    2     5     4   2,9544   1,8794   0,5209
# 3    604    114  16,2  19,7  22,5    1     1     0   0,9848   0,3473  -0,1736
# 4    605     94  17,4  20,5  20,4    8     8     7     -0,5  -2,9544  -4,3301
# ..   ...    ...   ...   ...   ...  ...   ...   ...      ...      ...      ...
# 107  925     84  13,3  17,7  17,8    3     5     6        0       -1  -1,2856
# 108  927     77  16,2  20,8  22,1    6     5     5  -0,6946       -2  -1,3681
# 109  928     99  16,9    23  22,6    6     4     7      1,5   0,8682   0,8682
# 110  929     83  16,9  19,8  22,1    6     5     3       -4  -3,7588       -4
# 111  930     70  15,7  18,6  20,7    7     7     7        0  -1,0419       -4
#
#      maxO3v   vent  pluie
# ...

# %%
print(dataframe.head(3))
# Out:
#    obs  maxO3    T9   T12   T15  Ne9  Ne12  Ne15      Vx9     Vx12     Vx15  \
# 0  601     87  15,6  18,5  18,4    4     4     8   0,6946  -1,7101  -0,6946
# 1  602     82    17  18,4  17,7    5     5     7  -4,3301       -4       -3
# 2  603     92  15,3  17,6  19,5    2     5     4   2,9544   1,8794   0,5209
#
#    maxO3v  vent pluie
# 0      84  Nord   Sec
# 1      87  Nord   Sec
# 2      82   Est   Sec

# %%
print(dataframe.iloc[100:111])
# Out:
#      obs  maxO3    T9   T12   T15  Ne9  Ne12  Ne15      Vx9     Vx12     Vx15  \
# 100  918     42  12,7  14,3  14,9    8     7     7     -2,5  -3,2139     -2,5
# 101  919     65  14,8  16,3  15,9    7     7     7  -4,3301  -6,0622  -5,1962
# 102  920     71  15,5    18  17,4    7     7     6  -3,9392  -3,0642        0
# 103  921     96  11,3  19,4  20,2    3     3     3  -0,1736   3,7588   3,8302
# 104  922     98  15,2  19,7  20,3    2     2     2        4        5   4,3301
# 105  923     92  14,7  17,6  18,2    1     4     6   5,1962   5,1423      3,5
# 106  924     76  13,3  17,7  17,7    7     7     6  -0,9397   -0,766     -0,5
# 107  925     84  13,3  17,7  17,8    3     5     6        0       -1  -1,2856
# 108  927     77  16,2  20,8  22,1    6     5     5  -0,6946       -2  -1,3681
# 109  928     99  16,9    23  22,6    6     4     7      1,5   0,8682   0,8682
# 110  929     83  16,9  19,8  22,1    6     5     3       -4  -3,7588       -4
#
#      maxO3v   vent  pluie
# ...

# %%
results = dataframe.loc[dataframe['vent'] == "Nord"]

# %%
print(results)
# Out:
#      obs  maxO3    T9   T12   T15  Ne9  Ne12  Ne15      Vx9     Vx12     Vx15  \
# 0    601     87  15,6  18,5  18,4    4     4     8   0,6946  -1,7101  -0,6946
# 1    602     82    17  18,4  17,7    5     5     7  -4,3301       -4       -3
# 3    604    114  16,2  19,7  22,5    1     1     0   0,9848   0,3473  -0,1736
# 7    610     79  14,9  17,5  18,9    5     5     4        0  -1,0419  -1,3892
# 8    611    101  16,1  19,6  21,4    2     4     4   -0,766  -1,0261  -2,2981
# 10   613    101  17,3  19,3  20,2    7     7     3     -1,5     -1,5  -0,8682
# 14   617     83  15,4  17,4  16,6    8     7     7  -4,3301  -2,0521       -3
# 17   621     81  16,2  22,4  23,4    8     3     1        0   0,3473  -2,5712
# 20   624    121  20,4  25,2  27,7    1     0     0        0  -0,5209   1,0261
# 27   701     70  18,8  22,7  24,9    5     2     1    0,684        0   1,3681
# 32   706     97  20,8  23,7    25    2     3     4        0   1,7101  -2,7362
# ...

# %%
results.reset_index()
# Out:
#     index  obs  maxO3    T9   T12   T15  Ne9  Ne12  Ne15      Vx9     Vx12  \
# 0       0  601     87  15,6  18,5  18,4    4     4     8   0,6946  -1,7101
# 1       1  602     82    17  18,4  17,7    5     5     7  -4,3301       -4
# 2       3  604    114  16,2  19,7  22,5    1     1     0   0,9848   0,3473
# 3       7  610     79  14,9  17,5  18,9    5     5     4        0  -1,0419
# 4       8  611    101  16,1  19,6  21,4    2     4     4   -0,766  -1,0261
# 5      10  613    101  17,3  19,3  20,2    7     7     3     -1,5     -1,5
# 6      14  617     83  15,4  17,4  16,6    8     7     7  -4,3301  -2,0521
# 7      17  621     81  16,2  22,4  23,4    8     3     1        0   0,3473
# 8      20  624    121  20,4  25,2  27,7    1     0     0        0  -0,5209
# 9      27  701     70  18,8  22,7  24,9    5     2     1    0,684        0
# 10     32  706     97  20,8  23,7    25    2     3     4        0   1,7101
# ...

# %%
print(dataframe["pluie"].unique())
# Out:
# <StringArray>
# ['Sec', 'Pluie']
# Length: 2, dtype: str

# %%
print(dataframe["T9"].unique())
# Out:
# <StringArray>
# ['15,6',   '17', '15,3', '16,2', '17,4', '17,7', '16,8', '14,9', '16,1',
#  '18,3', '17,3', '17,6', '17,1', '15,4', '15,9',   '21', '19,7', '23,6',
#  '20,4',   '27',   '24', '20,1', '19,6', '19,5', '18,8', '24,1', '26,6',
#  '20,8', '17,5', '18,1', '19,2', '19,4', '13,8', '14,3', '16,9', '15,1',
#  '16,7',   '18', '18,6',   '19', '19,9', '23,8', '23,3',   '25', '24,9',
#  '20,5', '25,3', '21,3',   '20', '18,7', '18,4', '17,8', '20,9', '23,5',
#  '20,6', '21,6', '22,7', '19,8', '16,5', '14,2', '15,8', '15,2', '13,7',
#  '12,7', '14,8', '15,5', '11,3', '14,7', '13,3', '15,7']
# Length: 70, dtype: str

# %%
print(dataframe.columns)
# Out:
# Index(['obs', 'maxO3', 'T9', 'T12', 'T15', 'Ne9', 'Ne12', 'Ne15', 'Vx9',
#        'Vx12', 'Vx15', 'maxO3v', 'vent', 'pluie'],
#       dtype='str')

# %%
print(dataframe[['vent', 'pluie']])
# Out:
#       vent  pluie
# 0     Nord    Sec
# 1     Nord    Sec
# 2      Est    Sec
# 3     Nord    Sec
# 4    Ouest    Sec
# ..     ...    ...
# 107    Sud    Sec
# 108    Sud  Pluie
# 109    Sud    Sec
# 110  Ouest  Pluie
# 111    Sud    Sec
#
# [112 rows x 2 columns]
